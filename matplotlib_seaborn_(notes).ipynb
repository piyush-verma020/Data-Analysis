# %% [markdown]
# # Visualization with Matplotlib and Seaborn
#
# Data Visualization is the graphic representation of data. It involves producing images that communicates realtionships among the represented data to viewers.
#
# Visualizing the data is an essential part of Data Analysis and Machine Learning.

# %%
# pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Points to be noted:
#
# * **%** here means “magic command” (not modulo).
#
# * It’s specific to ***IPython/Jupyter***, not general Python code.
#
# * It’s used for configuration or behavior control in notebooks.
#
# If you write this in a regular .py Python script, it will give a syntax error.
#
# #### Meaning of **%matplotlib** inline:
#
# * It tells Jupyter to display matplotlib plots directly below the code cell that produces them.
#
# * Without it, plots might open in a separate window(depending on the environment).
#
# * It helps make plots render ***“inline”*** — inside the notebook.

# %% [markdown]
# ### Line Chart
#
# Line charts are one of the simpliest and most widely used data visualization techniques.

# %%
apple = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
plt.plot(apple)

# %% [markdown]
# Calling the **plt.plto** function draws the line chart as expected, and also returns a list of plots drawn **[<matplotlib.lines.Line2D at 0x1ef2b621a90>]**
#
# shown within the output. We can include a semicolon(;) at the end of the last statement in the cell to avoid showing the output and just display the graph

# %%
plt.plot(apple);

# %% [markdown]
# You cannot use:
#
# **plt.plot(title='Apple Yield', yield_apple)**
#
# for both plooting and giving the graph it's title because this line gives an error because **plt.plot()** does not accept
#
# title as a keyword argument. Instead, **plt.plot()** is used to plot data, and **plt.title()** is used separately to set the title instead use:
#
# import matplotlib.pyplot as plt
#
# yield_apple = [3, 5, 7, 6, 8, 7]
#
# plt.plot(yield_apple)
#
# plt.title('Apple Yield')  # Setting the title separately
#
# ##### if you wish to add titles on x and the y axis then use:
#
# plt.xlabel('Year')        # Optional: label for x-axis
#
# plt.ylabel('Yield (tonnes)')  # Optional: label for y-axis
#
# plt.show()

# %%
years = range(2010, 2016)

# %%
plt.xlabel('Years')
plt.title('Crop Yields in Canto')  # "Canto" is an imaginary place somewhere in this cosmos
plt.ylabel('Yield (tonnes per hectare')
plt.plot(years, apple)
plt.show()

# %% [markdown]
# You can also plto more than one line graphs in the same or single graph

# %%
orange = [0.895, 0.941, 0.930, 0.923, 0.918, 0.908]

# %%
plt.plot(years,orange)
plt.plot(years,apple)

plt.xlabel('Years')
plt.ylabel('Yield( tonnes per hectare)')

plt.title('Crop Yields in Canto')  # "Canto" is an imaginary place somewhere in this cosmos
plt.show()

# %% [markdown]
# ### Chart Legend
#
# In order to differentiate between multiple lines, we can include legend within the graph using the **plt.legend** function

# %%
plt.xlabel('Years')
plt.ylabel('Yield (tonnes per hectare')

plt.title('Crop Yields in Canto')  # "Canto" is an imaginary place somewhere in this cosmos

plt.plot(years, apple)
plt.plot(years, orange)

plt.legend(['Apples', 'Orange'])
plt.show()

# %% [markdown]
# ### Line Markers
#
# We can also show markers for the data point on each line using the **marker** argument of **plt.plot**. Matplotlib supports different varieties of markers
# like circle, cross, triangle, diamond e.t.c.
#
# Here is the full list of markers:
#
# **https://matplot.org/3.1.1/api/markers_api.html**

# %%
plt.xlabel('Years')
plt.ylabel('Yield (tonnes per hectare')

plt.title('Crop Yields in Canto')  # "Canto" is an imaginary place somewhere in this cosmos

plt.plot(years, apple, marker='D')
plt.plot(years, orange, marker='d')

plt.legend(['Apples', 'Orange'])
plt.show()

# %% [markdown]
# ### Styling lines and markers
#
# The **plt.plot** function supports many argument for styling lines and markers:
# * **colour** or **c**: set the colour of the line (https://matplotlib.org/stable/gallery/color/named_colors.html)
# * **linestyle** or **ls**: choose between solid or dashed line
# * **linewidth** or **lw**: set the width of the line
# * **markersize** or **ms**: set the size of the marker
# * **markeredgecolour** or **mec**: set the edge colour for markers
# * **markerdgewidth** or **mew**: set the edge width for markers
# * **markerfacecolour** or **mfc**: set the fill colours for markers
# * **alpha**: opacity of the plot

# %%
plt.xlabel('Years')
plt.ylabel('Yield (tonnes per hectare')

plt.title('Crop Yields in Canto')  # "Canto" is an imaginary place somewhere in this cosmos

plt.plot(years, apple, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(years, orange, marker='o', c='r', ls='--', lw=3, ms=10, mec='black',mew=3, alpha=.5)

plt.legend(['Apples', 'Orange'])
plt.show()

# %% [markdown]
# The **fmt** argument provides a shorthand for specifying the line style, marker and line colour It can be provide as the third argument to **plt.plot**.
#
# The format of the **fmt** argument is:
#
# **fmt = '[marker][line_style][colour]'**
#
# #### Note:
#
# If no line style is specified in **fmt** argument, then **fmt** will draw only markers.
#
# Well this also alows you to add more colours and make a single plot look more attractive.

# %%
plt.xlabel('Years')
plt.ylabel('Yield (tonnes per hectare)')

plt.title('Crop Yields in Canto')  # "Canto" is an imaginary place somewhere in this cosmos

# Plotting Apple yield: blue square markers ('s'), then a black line for trend
plt.plot(years, apple, 'sb')  # Blue square markers for Apple
plt.plot(years, apple, ls='-', c='black', label='Apple')  # Black line for Apple trend

# Plotting Orange yield: red circle markers ('o') with a dashed line
plt.plot(years, orange, 'o--r', label='Orange')  # Red dashed line with circle markers

# Show legend (it uses labels provided in the plot() calls above)
plt.legend()  # Displays the legend with labels 'Apple' and 'Orange'

plt.show()

# %% [markdown]
# ### Changing the Figure Size
#
# You can use **plt.figure** function to change the size and aspect ration of the graph
#
# *Syntax:*

# %%
plt.figure(figsize=(6,3))

plt.plot(years, apple, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.show()

# %% [markdown]
# ## Inproving Default Style using Seaborn
#
# An easy way to make your charts look beautiful is by using the default styles provided by the Seaborn library.
# These can be applied globally using the **sns.set_style()** function. You can view the complete list of predefined styles here: https://seaborn.pydata.org/generated/seaborn.set_style.html

# %%
sns.set_style('whitegrid')

# %%
plt.xlabel('Years')
plt.ylabel('Yield (tonnes per hectare)')

plt.title('Crop Yields in Canto')

plt.plot(years, apple, 'sb')
plt.plot(years, apple, ls='-', c='black', label='Apple') 

plt.plot(years, orange, 'o--r', label='Orange') 

plt.legend()
plt.show()

# %%
sns.set_style('darkgrid')

# %%
plt.xlabel('Years')
plt.ylabel('Yield (tonnes per hectare)')

plt.title('Crop Yields in Canto')

plt.plot(years, apple, 'sb')
plt.plot(years, apple, ls='-', c='black', label='Apple') 

plt.plot(years, orange, 'o--r', label='Orange') 

plt.legend()
plt.show()

# %%
# Example showing that the style set by Seaborn is applied globally
plt.plot(years, apple,'or')

# %% [markdown]
# If you want you can also edit default styles by modifying the **matplotlib.rcParams**.
#
# Learn more about it here: https://matplotlib.org/stable/api/matplotlib_configuration_api.html

# %%
import matplotlib

# %%
matplotlib.rcParams # All the list of changes which could be made
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
plt.plot(years, apple,'or');

# %% [markdown]
# ### Scatter Plot
#
# In a sactter plot, the values of 2 variables are plotted as points of a 2-dimentional grid.
#
# Additionally you could also use a third variable to determine
# the size or the color of the points.
#
# The **Iris flower dataset** provides sample measurments of sepals and petals for 3 species of flower.
#
# The Iris dataset is included with the seaborn library,and can be loaded in Pandas Data Frame.

# %%
# Loading data into Pandas Data Frame
flower_df = sns.load_dataset('iris')

# %%
flower_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flower_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# Let's visualze the relationship between **sepal length** and **sepal width**. Let's create a line chart using **plt.plot()**.

# %%
plt.plot(flower_df.sepal_length, flower_df.sepal_width);

# %% [markdown]
# We can use scatter plot to visualize how sepal length and sepal width vary using the ***scatterplot** function* from seaborn(imported as sns)

# %% [markdown]
# ### Plotting with Pandas
#
# Seborn has in-built support for Pandas Data Frames. Instead of passing each column as series,
# you can also pass column names using the **data** argument to pass the Data Frame

# %%
sns.scatterplot(data=flower_df, x='sepal_length', y='sepal_width');

# %% [markdown]
# The resulting chart appears visually overwhelming, likely due to the high number of variable combinations in the dataset.
#
# This complexity makes it challenging to identify any straightforward or meaningful patterns.

# %% [markdown]
# ### Adding Hues

# %% [markdown]
# #### What is hue?
#
# * hue tells Seaborn to separate your data into categories based on a column's values.
#
# * It automatically assigns different colors to each unique value in that column.
#
# #### How to use hue:
#
# ##### sns.scatterplot(data=flower_df, x='sepal_length', y='sepal_width', hue='species');
#
# * We are plotting sepal length vs. sepal width.
#
# * The column species has 3 unique values: 'setosa', 'versicolor', 'virginica'.
#
# * hue='species' makes Seaborn:
#     * Group the points by species
#
#     * Assign a different color to each species
#
#     * Add a legend so you can understand which color represents which species}
#
# #### Visual Effect:
# So in our scatterplot, we see:
#
# * Red dots for Setosa
#
# * Blue dots for Versicolor
#
# * Green dots for Virginica
# (or other colors — depending on the theme)
#
# Each group is still plotted on the same X-Y space, but with its own color.

# %%
sns.scatterplot(data=flower_df, x='sepal_length', y='sepal_width', hue='species');

# %% [markdown]
# We could also increase the size of the dots by using s = 100 as another argument like:

# %%
sns.scatterplot(data=flower_df, x='sepal_length', y='sepal_width', hue='species',s=75);

# %% [markdown]
# It looks like adding hue makes the plot more informative. we can immediately tell thatthe flower of Setosa species have a smaller sepal length but higher
# sepal width, while the opposite is true for the flower of Virginica species.

# %% [markdown]
# ### Customizing Seaborn Figures
#
# Since seaborn uses matplotlib's plotting functions internally, we can use function like **plt.figure** and **plt.title**
# to modify the figure

# %%
plt.figure(figsize=(12,6))
plt.title('Sepal Dimension')

sns.scatterplot(data=flower_df, x='sepal_length', y='sepal_width', hue='species',s=75);

# %% [markdown]
# ### Histogram
#
# A histogram represents the distribution of data by forming bins along the range of the data and drawing bars showing
# the number of observations that fall in the bin.
#
# As an example, let's visualize how the values of sepal width in the flower data set are distributed.
# We can use the **plt.hist** function to create a hostogram.

# %%
flower_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
flower_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.title('Distribution of Sepal Width')
plt.hist(flower_df.sepal_width);
plt.show()

# %% [markdown]
# We can imediatly see that the values of sepal width in the range 2.0-4.5, and around 35 values are in the range 2.9-3.1, which seems to be the largest bin.

# %% [markdown]
# ### Controlling size and numbers of bins
#
# We can control the number and size of each bin just by using the **bins** argument

# %%
plt.hist(flower_df.sepal_width,bins=5);

# %%
import numpy as np

# Specifing the boundaries of each bin
plt.hist(flower_df.sepal_width, bins=np.arange(2,5,0.25));

# %%
# Bins of unequal size
plt.hist(flower_df.sepal_width, bins=[1,3,4,4.5]);

# %% [markdown]
# ### Multiple Histograms
#
# Similar to line charts, we can draw multiple histogram in a singhe chart. We can reduce the opacity(or alpha) of each histogram, so the bar of one doesn't
# hides the other.

# %%
flower_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
species1 = flower_df[flower_df.species == 'setosa']

# %%
species2 = flower_df[flower_df['species'] == 'versicolor']

# %%
species3 = flower_df[flower_df.species == 'virginica']

# %%
plt.title('Distribution of Sepal Width')
plt.hist(species1.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25),label = 'Setosa');
plt.hist(species2.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25),label = 'Versicolor');
plt.legend()
plt.show()

# %%
plt.title('Distribution of Sepal Width')
plt.hist([species1.sepal_width, species2.sepal_width, species3.sepal_width], bins=np.arange(2,5,0.25), stacked=True, alpha = 0.75)
plt.legend(['Setosa', 'Versicolor', 'Virginica'])
plt.show()

# %%
# If not stacked
plt.title('Distribution of Sepal Width')
plt.hist([species1.sepal_width, species2.sepal_width, species3.sepal_width], bins=np.arange(2,5,0.25), stacked=False)
plt.legend(['Setosa', 'Versicolor', 'Virginica'])
plt.show()

# %% [markdown]
# ### Bar Chart
#
# Bar charts are quite similar to line chart i.e. they show a sequence of values, however a bar is show for each value, rather
# than points connected by lines.
#
# We can use **plt.bar** to plot a bar chart

# %%
years = range(2000,2006)
apples = [0.35,0.6,0.9,0.8,0.65,0.8]
oranges = [0.4,0.8,0.9,0.7,0.6,0.8]

# %%
plt.bar(years,apples);

# %% [markdown]
# We can also plot bar and line charts together like

# %%
plt.bar(years,oranges);
plt.plot(years,oranges,'s--r');
plt.title("Yield of Oranges")
plt.show()

# %% [markdown]
# Just like histograms, bars can also be stacked on top of one another by using the **bottom** argument in **plt.bar**

# %%
plt.bar(years,apples);
plt.bar(years, oranges, bottom=apples);

# %% [markdown]
# ### Bars Plots with Averages
#
# Let's look at another dataset included in Seaborn, called **'tips'**. This dataset contains information such as the sex of the customer,
# time of day, total bill, and tip amount for customers visiting a restaurant over the course of a week.

# %%
tips_df = sns.load_dataset('tips');

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# We might want to plot a bar chart to visualize how the average bill amout varies across different days of the week.
# One way to do this would be to compute the day-wise averages and the use **plt.bar**.
#
# However this is a very common use case, the seaborn library provides a **barplot** function which can automatically compute averages.

# %% [markdown]
# ##### Seaborn changed the format slightly in more recent versions, and now it requires that x and y be passed as keyword arguments (instead of positional ones)
#
# sns.barplot('day','total_bill',data=tips_df);
#
# instead of using the above code use this instead:
#
# **sns.barplot(x='day',y='total_bill',data=tips_df);**

# %%
sns.barplot(x='day',y='total_bill',data=tips_df);

# %% [markdown]
# The lines cutting each bar represents the amount of variation in the values. For instance it seems like the variation in the total bill was quite high on
# Friday and lower on Saturday.

# %%
tips_df.groupby('day')[['total_bill']].mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3728\1834733059.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_df.groupby('day')[['total_bill']].mean()
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %% [markdown]
# **FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas.**
# **Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.**
#
# **tips_df.groupby('day')[['total_bill']].mean()**
#
# This is not an error, just a warning from pandas.
#
# It’s saying that in future versions, the default behavior of groupby() will change slightly.
#
# Right now, it shows all possible categories (like all 7 days of the week), even if some (like Monday, Tuesday, and Wednesday) are not in the dataset.
#
# In the future, it will only show the days that actually appear in your data (Thursday, Friday, Saturday, Sunday — in the case of the tips dataset).
#
# To avoid the warning and be future-proof, you can write:
#
# **tips_df.groupby('day', observed=True)[['total_bill']].mean()**

# %%
bill_avg_df = tips_df.groupby('day', observed=True)[['total_bill']].mean() # This time no future errors will be seen

# %%
sns.barplot(x = 'day', y = 'total_bill', data = bill_avg_df); # Well you could just use plt.bar(bill_avg_df.day, bill_avg_df.total_bill)

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips_df);

# %% [markdown]
# We can also specify a **hue** argument to compare bar plots side-by-side based on third feature example **sex**.

# %%
bill_avg_df = tips_df.groupby(['day', 'sex'])[['total_bill']].mean().reset_index()
sns.barplot(x = 'day', y = 'total_bill',hue='sex', data = bill_avg_df);
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3728\1760108322.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bill_avg_df = tips_df.groupby(['day', 'sex'])[['total_bill']].mean().reset_index()

# %% [markdown]
# You could make the bars horizontal just by switching the axes (the values of x and y).

# %%
sns.barplot(y = 'day', x = 'total_bill',hue='sex', data = bill_avg_df);

# %%
sns.barplot(x = 'day', y = 'total_bill',hue='smoker', data = tips_df);

# %% [markdown]
# This is how you can use multiple features with the **hue** parameter to compare plots.
#
# However, you cannot pass a list to **hue**, hoping it will automatically perform the comparison for you.

# %%
tips_df['smoker_sex'] = tips_df['smoker'].astype(str) + ' ' + tips_df['sex'].astype(str)

# %%
sns.barplot(x='day', y='total_bill', hue='smoker_sex', data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Heatmap
#
# A heatmap is used to visualize 2-Dimentional data just like a matrix or a table using colors.
# The best way to understand is by looking at an example.
# We will be using another sample dataset from Seaborn called **'flights'**, to visualize monthly passenger footfall at an airport over 12 years

# %%
flights_df = sns.load_dataset('flights')

# %%
flights_df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot(flights_df.passengers);

# %% [markdown]
# The **.pivot()** function in pandas is used to reshape a DataFrame — it allows us to turn unique values from one column into column headers and reorganize your data into a more readable table/matrix format.
#
# Now when we apply **.pivot()** like:
#
# **pivoted_df = flights_df.pivot(index='month', columns='year', values='passengers')**

# %%
pivoted_df = flights_df.pivot(index='month', columns='year', values='passengers')

# %%
pivoted_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# Now each month is a row, each year is a column, and each cell contains passenger numbers.
#
# ##### Points to be noted:
#
# * The combination of index and columns must be unique. If not, use .pivot_table() instead.
#
# * Use .pivot() when you're reshaping clean, non-repeating data.
#
# ---

# %% [markdown]
# #### **Difference between .pivot() and .pivot_table():**
#
# #### .pivot():
#
# * Simple reshaping
#
# * Requires unique combinations of index and columns
#
# * Will throw an error if there are duplicates
#
# **Syntax:**
#
# **pivoted_df = df.pivot(index='month', columns='year', values='passengers')**
#
# #### Note:
#
# **This only works if there’s exactly one value per month-year pair.**
#
# ---
#
# #### .pivot_table():
#
# * More flexible and powerful
#
# * Can handle duplicate entries
#
# * Allows aggregation (mean, sum, etc.) over duplicates
#
# **Syantax:**
#
# **pivot_table_df = df.pivot_table(index='month', columns='year', values='passengers', aggfunc='mean')**
#
# #### Note:
#
# **Even if a month-year combination appears multiple times, it will take the mean (or any function you choose) of those values.**
#
# ---

# %% [markdown]
# **pivoted_df** is a matrix with one row for each month and one column for each year. The values in the matrix show the number of passengers (in thousands)
# that visited the airport in a specific month of a specific year.
#
# We can use the **sns.heatmap** function to visualize the footfall at the airport.

# %%
plt.title("No. of Passengers (in 1000's)")
sns.heatmap(pivoted_df);

# %% [markdown]
# The brighter color indicates higher footfall at the airport. By looking at the graph we can infer two things:
#
# 1. The footfall at the airport at any year tends to be the highest around July and August.
# 2. The footfall at the airport at any given month tends to grow year by year.
#
# We can display the actual values in each block by specifying **annot=True**, and use the **cmap** argument to change the color palette.

# %%
plt.title("No. of Passengers (in 1000's)")
sns.heatmap(pivoted_df, fmt = 'd', annot=True, cmap='Blues');

# %% [markdown]
# #### What is the purpose of fmt='d' in sns.heatmap()?
#
# * fmt stands for "format" — it controls how the numbers are displayed inside each cell when annot=True is used.
#
# * fmt='d' means: format the annotations as decimal integers (whole numbers).
#
# So, if the numbers in your heatmap are integers like 150, 200, 300, etc., this will display them exactly as-is.
#
# #### Why do you see values like 1e+02, 2e+02, etc., when fmt is not provided?
#
# That’s because by default:
#
# * matplotlib tries to automatically format numbers, and
#
# * If values are large (e.g., in hundreds or thousands), it may switch to scientific notation like 1e+02 = 100, 2e+02 = 200.
#
# #### How to avoid scientific notation or control number formatting:
#
# * fmt='d' → for integers (e.g., 150, 200, 300)
#
# * fmt='.0f' → for floats without decimals (e.g., 150.0 becomes 150)
#
# * fmt='.1f', '.2f', etc. → for floats with 1 or 2 decimal places (e.g., 123.45)
#
# ---

# %% [markdown]
# | Purpose                     | `cmap` name                                                  | Description                                              |
#
# | --------------------------- | ------------------------------------------------------------ | -------------------------------------------------------- |
#
# | Sequential (light to dark)  | `'Blues'`, `'Greens'`, `'Reds'`, `'Oranges'`, `'Purples'`    | Good for showing increasing values                       |
#
# | Diverging (centered values) | `'coolwarm'`, `'RdBu'`, `'Spectral'`, `'PiYG'`               | Good for data with a central midpoint (e.g., +/− change) |
#
# | Cyclical                    | `'twilight'`, `'hsv'`                                        | Best for circular data (like time, angles)               |
#
# | Perceptually uniform        | `'viridis'`, `'plasma'`, `'inferno'`, `'magma'`, `'cividis'` | Color-safe for people with color blindness               |
#
# | Others (fun or fancy)       | `'cubehelix'`, `'YlGnBu'`, `'BuPu'`, `'GnBu'`                | Aesthetic options for different vibes                    |

# %%
plt.title("No. of Passengers (in 1000's)")
sns.heatmap(pivoted_df, fmt = 'd', annot=True, cmap='cubehelix');

# %% [markdown]
# In this aesthetic colormap **cmap**, the color variation goes from darker to lighter. If you wish to reverse the color composition, add **_r** to the **cmap name**.
#
# Syntax:

# %%
plt.title("No. of Passengers (in 1000's)")
sns.heatmap(pivoted_df, fmt = 'd', annot=True, cmap='cubehelix_r');

# %% [markdown]
# ## Displaying images with matplotlib
#
# Matplotlib can also be used for displaying images. Let's download an image from the internet by using **urllib.request**.

# %%
import urllib.request

# %%
url = 'https://i.imgur.com/SkPbq.jpeg'
headers = {'User-Agent': 'Mozilla/5.0'}

req = urllib.request.Request(url, headers=headers)

# %%
with urllib.request.urlopen(req) as response, open('chart.jpg', 'wb') as out_file:
    out_file.write(response.read())

# %% [markdown]
# Before an image can be loaded it has to be read into memory using the **PIL** module

# %%
from PIL import Image

# %%
# Open the image
img = Image.open('chart.jpg')

# %% [markdown]
# We can display the PIL image using **plt.imshow()**

# %%
# Displaying the image
plt.imshow(img);

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# An image loaded using **PIL** is simply a 3-dimentioanl numpy array containing pixel intensities for red, green and blue (RGB) channels of the image.
#
# We can convert the image into an array using **np.array**.

# %%
img_array = np.array(img)

# %%
img_array.shape
# Out:
# (481, 640, 3)

# %%
# img_array # This shows dimention of image and the pixel defination i.e the color of the pixel

# %% [markdown]
# We can turn off the axes and grid lines, and also show a title using a relevant functions.

# %%
plt.grid(False)
plt.title("A Data Science Meme")
plt.axis('off')
plt.imshow(img);

# %% [markdown]
# Since the image is an array we can also display a part of the image, we can simply select a slice from the numpy array.

# %%
plt.imshow(img);

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(img_array[125:325,105:305]);

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(img_array[55:165,365:465]);

# %% [markdown]
# When we do something like:
#
# **img_array[55:165, 365:465]**
#
# We're actually slicing a NumPy array, and in NumPy (as in most image-processing libraries like OpenCV and PIL), the indexing follows the format:
#
# **array[y, x] → [row, column]**
#
# #### Important distinction:
#
# * In matplotlib’s plotting functions, like plt.plot(x, y), you specify x first and y second, because that’s standard Cartesian format.
#
# * In image arrays, it's **[y, x]** because:
#
#     * Arrays are 2D: **array[rows, columns]**
#
#     * Images are grids of pixels arranged as **rows (top to bottom)** and **columns (left to right)**
#
# But the image we downloaded is stored as a 3D array, typically shaped like:
#
# ---
#
# (height, width, channels)
#
#    Y,       X,     (R,G,B)
#
# ---
#
# So when you index an image like:
#
# **img_array[55:165, 365:465]**
#
# You're still following this rule:
#
# **img_array[y_range, x_range, :]**
#
# Where:
#
# * y_range → vertical range (rows)
#
# * x_range → horizontal range (columns)
#
# * : → all 3 color channels (RGB)
#
# #### Example:
#
# The image shape is:
#
# **img_array.shape** #Output: (300, 500, 3)
#
# This means:
#
# * 300 pixels in height (Y axis / rows)
#
# * 500 pixels in width (X axis / columns)
#
# * 3 color channels (Red, Green, Blue)
#
# #### Key Insight:
#
# Even though it's a 3D array, the spatial dimensions **(height and width)** are always accessed in **[y, x]** order.
# The third dimension just adds color depth, and isn't involved in positioning.
#
# ---

# %% [markdown]
# ### Plotting multiple charts in a grid
#
# Matplotlib and Seaborn also support plotting multiple charts in a grid, using **plt.subplots**, which returns a set of axes that can be used for plotting.

# %%
fig, axes = plt.subplots(2,3,figsize=(12,9));
plt.tight_layout(pad=2)  # You can increase the spacing between the sub plots just by increasing the pad number

# %% [markdown]
# ### What is constrained_layout=True?
#
# constrained_layout is a layout engine in Matplotlib that automatically adjusts the spacing between subplots to prevent overlaps of:
#
# * titles
#
# * axis labels
#
# * tick labels
#
# * legends
#
# * and even colorbars
#
# When you set **constrained_layout=True** in *plt.subplots()* or *plt.figure()*, Matplotlib tries to fit all subplot elements neatly within the figure canvas without them running into each other or being clipped.
#
# ### Why and When to Use It?
#
# * When you have multiple subplots (like in a grid) and labels or titles start overlapping.
#
# * When you're using legends, colorbars, or long axis labels, and manual spacing becomes tedious.
#
# * It’s a better and more modern alternative to the older **plt.tight_layout()**.
#
# ### How it works behind the scenes
#
# * Matplotlib calculates how much space each subplot and its decorations (like labels, ticks, titles) take.
#
# * It then adjusts the spacing between subplots and the figure margins to make everything fit neatly.
#
# * Unlike **tight_layout**, **constrained_layout** works even better with complex layouts (e.g. subplots + colorbars + text).

# %%
fig, axes = plt.subplots(2, 3, figsize=(12,9), constrained_layout=True)

# %%
axes.shape
# Out:
# (2, 3)

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 10), constrained_layout=True)

axes[0,0].plot(years,oranges,'s--r');
axes[0,0].set_title('Yield of Oranges')
axes[0,0].set_xlabel('Years')
axes[0,0].set_ylabel('Yield (tonnes per hectare)')
axes[0,0].legend('Oranges')

axes[0,1].set_xlabel('Years')
axes[0,1].set_ylabel('Yield (tonnes / hectare)')
axes[0,1].plot(years, apple, 'sb');
axes[0,1].plot(years, apple, ls='-', c='black', label='Apple'); 
axes[0,1].plot(years, orange, 'o--r', label='Orange');
axes[0,1].set_title('Crop Yields in Canto')
axes[0,1].legend()

axes[0,2].set_title('Resturent Bills')
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df,ax=axes[0,2]);

axes[1,0].set_title('Meme')
axes[1,0].grid(False)
axes[1,0].axis('off')
axes[1,0].set_xticks([])
axes[1,0].set_yticks([])
# The set_xticks or the yticks remove the tick marks and the tick labels, which are the visual indicators of coordinate positions along the x and y axes.
axes[1,0].imshow(img);

axes[1,1].set_title('Sepal Dimension')
sns.scatterplot(data=flower_df, x='sepal_length', y='sepal_width', hue='species',s=50,ax=axes[1,1]);

axes[1,2].set_title("No. of Passengers (in 1000's)")
sns.heatmap(pivoted_df, ax=axes[1,2]);

# %% [markdown]
# You cannot call .heatmap() on a matplotlib axis object (axes[1,2]). The heatmap() function is part of Seaborn, not a method on an axis object like set_title() is.
#
# To fix it, you should pass the axis to sns.heatmap() using the ax parameter like this:
#
# **axes[1,2].set_title("No. of Passengers (in 1000's)")**
#
# **sns.heatmap(pivoted_df, ax=axes[1,2])**
#
# because:
# **sns.heatmap() → is a Seaborn function that draws on an axes if you provide it using ax=....**
#
# ---
#
# #### Top Row (Row 0) — Time Series and Bar Plots
#
# 1. axes[0,0] — Line Plot for Oranges:
#
#     * A simple line plot of orange yield over years using 's--r' (square markers with red dashed lines).
#
#     * Axis labels and a title are added for clarity.
#
#     * A legend helps identify the plot as representing “Oranges”.
#
# 2. axes[0,1] — Multi-Line Plot:
#
#     * Multiple crop yields (Apple and Orange) are plotted with distinct markers and line styles.
#
#     * This comparison-style plot clearly distinguishes between the crops with a legend.
#
#     * Common x and y labels describe the time and unit of measurement.
#
# 3. axes[0,2] — Bar + Line Plot:
#
#     * Combines a bar chart and a line chart for orange yield, providing a visual cross-reference.
#
#     * This hybrid visualization is effective in comparing trends alongside absolute values.
#
# 4. axes[1,0] — Cropped Image Display:
#
#     * An image array (likely from PIL and converted to NumPy) is displayed using imshow().
#
#     * The grid and axes are turned off to emphasize only the image.
#
#     * The slicing img_array[55:165,365:465] focuses on a specific part of the image — indexing is done in the [y, x] order due to array structure.
#
# 5. axes[1,1] — Seaborn Scatterplot:
#
#     * A scatterplot shows the relationship between sepal length and width in the flower_df dataset.
#
#     * Hue is used to differentiate species, and the plot is directed to the specified subplot (ax=axes[1,1]).
#
# 6. axes[1,2] — Seaborn Heatmap:
#
#     * A heatmap of a pivoted DataFrame (pivoted_df) visualizes the number of passengers.
#
#     * The color intensity reflects the value magnitude, and the title describes the chart content
#
# #### Why This Works Smoothly:
#
# * Subplot Indexing: We access each subplot using axes[row, col], making it intuitive and organized.
#
# * constrained_layout=True prevents overlapping and auto-manages spacing.
#
# * Seaborn Integration: By passing ax=axes[...] to Seaborn functions, we ensure the plots are embedded correctly in the subplot grid.
#
# * Visual Variety: This layout combines line plots, bar charts, scatter plots, heatmaps, and image rendering — showcasing the versatility of Matplotlib and Seaborn when used together.

# %% [markdown]
# ### Pair plots with Seaborn
#
# Seaborn also a helper function **sns.pairplot** to automatically plot different types of charts with pairs of features within a dataframe.

# %%
sns.pairplot(flower_df,hue='species');

# %% [markdown]
# # How to read the pairplot:
#
# Imagine your DataFrame looks like this:
#
# | sepal\_length | sepal\_width | petal\_length | petal\_width | species    |
# | ------------- | ------------ | ------------- | ------------ | ---------- |
# | 5.1           | 3.5          | 1.4           | 0.2          | setosa     |
# | 7.0           | 3.2          | 4.7           | 1.4          | versicolor |
# | ...           | ...          | ...           | ...          | ...        |
#
# The pairplot creates a grid of plots, like this:
#
# |                   | sepal\_length | sepal\_width | petal\_length | petal\_width |
# | ----------------- | ------------- | ------------ | ------------- | ------------ |
# | **sepal\_length** | histogram     | scatter      | scatter       | scatter      |
# | **sepal\_width**  | scatter       | histogram    | scatter       | scatter      |
# | **petal\_length** | scatter       | scatter      | histogram     | scatter      |
# | **petal\_width**  | scatter       | scatter      | scatter       | histogram    |
#
# ### Upper and Lower Triangles = Scatter Plots
#
# * These show correlations between pairs of features:
#
# * Each dot is a flower.
#
# * The position represents two feature values (like sepal width vs petal width).
#
# * The color (thanks to **hue='species'**) tells you the species.
#
# If dots of different colors are separated, the features are good at distinguishing species.
# If dots are mixed, those features may not be useful for classification.
#
# ### Diagonal = Histograms / KDE plots
#
# These show the distribution of each single feature, per species.
#
# * If **kind='kde'**, you'll see wave-like smooth curves **(KDE = kernel density estimate)**.
#
# * If **kind='hist'** (default), you'll see bar histograms.
#
# So the wave-like shapes you're seeing are probability density plots showing how feature values are spread for each species.
#
# ### TL;DR Summary:
#
# * Scatter plots = relationship between two features.
#
# * Diagonal plots = distribution of a single feature.
#
# * Color = represents the species (as given by hue).
#
# * Well-separated dots = useful features for classification.
#
# * Mixed dots = less useful.

# %%
sns.pairplot(tips_df,hue='sex');

# %% [markdown]
# # Further Reading
#
# Data Visualization cheat sheet: https://jovian.ml/aakashns/dataviz-cheatsheet
#
# Seaborn gallery: https://seaborn.pydata.org/examples/index.html
#
# Matplotlib gallery: https://matplotlib.org/3.1.1/gallery/index.html
#
# Matplotlib tutorial: https://github.com/rougier/matplotlib-tutorial
